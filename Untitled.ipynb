# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
# %load_ext tensorboard

# %%
tensorboard --logdir='experiments/version_test_ddp' --port=16007
# Out:
#       <iframe id="tensorboard-frame-f6529d320accc60f" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-f6529d320accc60f");
#           const url = new URL("/", window.location);
#           const port = 16007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# !python3 training.py --batch_size 2 --max_epochs 200 --image_encoder_model 'resnet_2plus1' --name_board 'test_ddp' --part 3 --divided_text False --file_name 'test_ddp' --pretrained False --out_dim 100
# Out:
# /usr/lib/python3.6/importlib/__init__.py:126: FutureWarning: MLflow support for Python 3.6 is deprecated and will be dropped in an upcoming release. At that point, existing Python 3.6 workflows that use MLflow will continue to work without modification, but Python 3.6 users will no longer get access to the latest MLflow features and bugfixes. We recommend that you upgrade to Python 3.7 or newer.
#   return _bootstrap._gcd_import(name[level:], package, level)
# "accumulate_grad_batches": 1
# "alpha_weight":            0.5
# "augmentations":           False
# "batch_size":              2
# "bucket_size":             32
# "divided_text":            True
# "embeds_file":             2ch_gr
# "file_name":               test_ddp
# "freeze_layers":           [0, 1, 2, 3]
# "gpus":                    [0, 3]
# "image_encoder_model":     resnet_2plus1
# "learning_rate":           1e-05
# "loader_workers":          1
# "max_epochs":              200
# "metric_mode":             min
# ...

# %%
# !python3 training.py --batch_size 2 --phase 'test'  --embeds_file 'gn_ddp'
# Out:
# /usr/lib/python3.6/importlib/__init__.py:126: FutureWarning: MLflow support for Python 3.6 is deprecated and will be dropped in an upcoming release. At that point, existing Python 3.6 workflows that use MLflow will continue to work without modification, but Python 3.6 users will no longer get access to the latest MLflow features and bugfixes. We recommend that you upgrade to Python 3.7 or newer.
#   return _bootstrap._gcd_import(name[level:], package, level)
# "accumulate_grad_batches": 1
# "alpha_weight":            0.5
# "augmentations":           False
# "batch_size":              2
# "bucket_size":             32
# "divided_text":            True
# "embeds_file":             gn_ddp
# "file_name":               tmp
# "freeze_layers":           [0, 1, 2, 3]
# "gpus":                    [0, 3]
# "image_encoder_model":     resnet18_3D
# "learning_rate":           1e-05
# "loader_workers":          1
# "max_epochs":              20
# "metric_mode":             min
# ...
